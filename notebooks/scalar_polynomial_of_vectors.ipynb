# %% [markdown]
# # Scalar function of vectors, polynomial edition
#
# ## Authors:
# - **Hogg**
#
# ## Data:
# - Get data from Saydjari.
#
# ## Issues:
# - Not even started.

# %%
import h5py
import jax.numpy as jnp
import pylab as plt
import numpy.random as random
